# %% [markdown]
# ## Exercise: plotting

# %%
df.plot.scatter('player1 aces', 'player1 total points won');

# %% [markdown]
# ## Exercise: sumsquares

# %%
def sumsquares(a, b, X, Y):
    Yhat = a * X + b
    residuals = Y - Yhat
    return (residuals**2).sum()
