# %% [markdown]
# # Seeds dataset with decision trees
#
# During the session we classified the seeds dataset with KNN. Now let's try to classify it with decision trees!

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import warnings
warnings.simplefilter("ignore", FutureWarning)

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

import sklearn.datasets

from yellowbrick.classifier import class_prediction_error
from yellowbrick.features import feature_importances
from yellowbrick.model_selection import learning_curve

red, blue, green = sns.color_palette('Set1', 3)
sns.set(
    style='ticks',
    context='talk',
    palette='Set1'
)

# %% [markdown]
# If you had a problem importing Yellowbrick, create a new cell and run the following command in it:
# ```
# !pip3 install yellowbrick
# ```

# %% [markdown]
# We start by loading the data.

# %%
df = pd.read_csv('../data/seeds_dataset.txt', sep='\t')
df.head()
# Out:
#     area  perimeter  compactness  kernel_length  kernel_width  asymmetry  \
# 0  15.26      14.84       0.8710          5.763         3.312      2.221
# 1  14.88      14.57       0.8811          5.554         3.333      1.018
# 2  14.29      14.09       0.9050          5.291         3.337      2.699
# 3  13.84      13.94       0.8955          5.324         3.379      2.259
# 4  16.14      14.99       0.9034          5.658         3.562      1.355
#
#    kernel_groove  cultivar
# 0          5.220         1
# 1          4.956         1
# 2          4.825         1
# 3          4.805         1
# 4          5.175         1

# %%
target_name = 'cultivar'
feature_names = list(df.columns)
feature_names.remove(target_name)


X = df[feature_names].values
y = df[target_name].values

# %% [markdown]
# First, **split the data** to train and test sets.

# %% [markdown]
# Second, **create, fit and score** a decision tree (or random forest) classifier.

# %%
# Out:
# Accuracy =  0.9

# %% [markdown]
# **Plot a features importance plot** to determine the most important features using yellowbrick's `feature_importance` function.

# %% [markdown]
# **Plot a learning curve** to find out how many samples are required to train the model.

# %% [markdown]
# **End.**
